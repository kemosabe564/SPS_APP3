# %%
# getting map from layout.png file
# current resolution is 1px-0.01m

# %%
from PIL import Image
import numpy as np

# %%
I = Image.open('./layout_test.png') 
I.show()    
I_array = np.array(I)
print (I_array.shape)
I_length = I_array.shape[0]
I_width  = I_array.shape[1]
# print (I_array[0][I_width-50] == [0, 0, 0])
# print(I_width)
# Out:
# (404, 422, 3)

# %%
# reset txt file
with open("layout_map.txt","a") as f:
    f.truncate(0)

# write txt file
for i in range(I_length):
    for j in range(I_width):
        if (I_array[i][j] == [0, 0, 0]).all():
            x = round(0.01*(i),2)
            y = round(0.01*(j),2)
            data1 = str(x) + ", " + str(y) + ", " + "0"
            with open("layout_map.txt","a") as f:
                f.writelines(data1)
                if !(i == I_length-1 and j == I_width-1):
                    f.writelines("\n")
                
    print("OK")
# Out:
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-728d506c2a05> in <module>
#       4
#       5 # write txt file
# ----> 6 for i in range(I_length):
#       7     for j in range(I_width):
#       8         if (I_array[i][j] == [0, 0, 0]).all():
#
# NameError: name 'I_length' is not defined
