# %%
# getting map from layout.png file
# current resolution is 1px-0.01m

# %%
from PIL import Image
import numpy as np

# %%
I = Image.open('./layout_test.png') 
I.show()    
I_array = np.array(I)
print (I_array.shape)
I_length = I_array.shape[0]
I_width  = I_array.shape[1]
# print (I_array[0][I_width-50] == [0, 0, 0])
# print(I_width)
# Out:
# (404, 422, 3)

# %%
# Out:
# [ True  True  True]
# 422

# %%
# reset txt file
with open("layout_map.txt","a") as f:
    f.truncate(0)

# write txt file
for i in range(I_length):
    for j in range(I_width):
        if (I_array[i][j] == [0, 0, 0]).all():
            x = 0.01*(i)
            y = 0.01*(j)
            data1 = str(x) + ", " + str(y) + ", " + "0"
            with open("layout_map.txt","a") as f:
                f.writelines(data1)
                f.writelines("\n")
    print("OK")
# Out:
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-52-cf2697db29cf> in <module>
#      10             y = 0.01*(j)
#      11             data1 = str(x) + ", " + str(y) + ", " + "0"
# ---> 12             with open("layout_map.txt","a") as f:
#      13                 f.writelines(data1)
#      14                 f.writelines("\n")
#
# PermissionError: [Errno 13] Permission denied: 'layout_map.txt'
